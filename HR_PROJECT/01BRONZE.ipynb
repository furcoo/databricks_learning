# %% [markdown]
# #项目：HR_PROJECT
# ##这是用来处理接入层的数据

# %% [markdown]
# ##删除数据

# %%
# %sql 
truncate TABLE uc_data001.uc_schema001.raw_hr_employees;
truncate TABLE uc_data001.uc_schema001.raw_hr_employees_countries;
truncate TABLE uc_data001.uc_schema001.raw_hr_employees_departments;
truncate TABLE uc_data001.uc_schema001.raw_hr_employees_locations;

# %%
# %sql

COPY INTO uc_data001.uc_schema001.raw_hr_employees FROM
'/Volumes/uc_data001/uc_schema001/volume001/Employees/employees1*.csv'
FILEFORMAT = CSV FORMAT_OPTIONS ('header' = 'true')
;

COPY INTO uc_data001.uc_schema001.raw_hr_employees_countries FROM
'/Volumes/uc_data001/uc_schema001/volume001/Employees/countries*.csv'
FILEFORMAT = CSV FORMAT_OPTIONS ('header' = 'true')
;

COPY INTO uc_data001.uc_schema001.raw_hr_employees_departments FROM
'/Volumes/uc_data001/uc_schema001/volume001/Employees/departments*.csv'
FILEFORMAT = CSV FORMAT_OPTIONS ('header' = 'true')
;

COPY INTO uc_data001.uc_schema001.raw_hr_employees_locations FROM
'/Volumes/uc_data001/uc_schema001/volume001/Employees/locations*.csv'
FILEFORMAT = CSV FORMAT_OPTIONS ('header' = 'true')
;
